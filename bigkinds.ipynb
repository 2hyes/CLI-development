# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup


html = urlopen('https://www.bigkinds.or.kr/v2/news/search.do;Bigkinds=1A8A57D74E55A5EE71CB2CF9D7D11DF2')
headers = {"User-gent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.102 Safari/537.36"}
bs = BeautifulSoup(html, 'html.parser')

# %%
bs.findAll("div")
# Out:
# [<div>
#  <a class="skip" href="#contents">본문 바로가기</a>
#  <a class="skip" href="#app-navbar">주메뉴 바로가기</a>
#  </div>,
#  <div class="navbar" id="app-top-navs">
#  <div class="container">
#  <div class="" id="app-top-navbar">
#  <ul class="nav navbar-nav navbar-right">
#  <!--
#                  <li>
#                      <a href="#" class="theme-btn theme-default" data-theme="default">
#                          <i class="fa fa-palette"></i>
#                      </a>
#                  </li>
#                  <li>
#                      <a href="#" class="theme-btn theme-dark" data-theme="dark">
#                          <i class="fa fa-palette"></i>
#                      </a>
#                  </li>
#                  -->
#  <li>
#  <a class="login-modal-btn login-link session-link active" data-toggle="modal" href="#">
#                          로그인
#                      </a>
#  </li>
#  <li>
#  <a class="signup-modal-btn signup-link session-link active" href="#">
# ...

# %%
bs.findAll("div", {"class":"container"})
# Out:
# [<div class="container">
#  <div class="" id="app-top-navbar">
#  <ul class="nav navbar-nav navbar-right">
#  <!--
#                  <li>
#                      <a href="#" class="theme-btn theme-default" data-theme="default">
#                          <i class="fa fa-palette"></i>
#                      </a>
#                  </li>
#                  <li>
#                      <a href="#" class="theme-btn theme-dark" data-theme="dark">
#                          <i class="fa fa-palette"></i>
#                      </a>
#                  </li>
#                  -->
#  <li>
#  <a class="login-modal-btn login-link session-link active" data-toggle="modal" href="#">
#                          로그인
#                      </a>
#  </li>
#  <li>
#  <a class="signup-modal-btn signup-link session-link active" href="#">
#                          회원가입
#                      </a>
#  </li>
#  <li>
# ...

# %%
bs.find_all(attrs={'class':'page-info'})
# Out:
# []

# %%
bs.select(" .container")
# Out:
# [<div class="container">
#  <div class="" id="app-top-navbar">
#  <ul class="nav navbar-nav navbar-right">
#  <!--
#                  <li>
#                      <a href="#" class="theme-btn theme-default" data-theme="default">
#                          <i class="fa fa-palette"></i>
#                      </a>
#                  </li>
#                  <li>
#                      <a href="#" class="theme-btn theme-dark" data-theme="dark">
#                          <i class="fa fa-palette"></i>
#                      </a>
#                  </li>
#                  -->
#  <li>
#  <a class="login-modal-btn login-link session-link active" data-toggle="modal" href="#">
#                          로그인
#                      </a>
#  </li>
#  <li>
#  <a class="signup-modal-btn signup-link session-link active" href="#">
#                          회원가입
#                      </a>
#  </li>
#  <li>
# ...

# %%
print(bs)
# Out:
# <!DOCTYPE HTML>
#
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <link href="https://www.bigkinds.or.kr" rel="canonical"/>
# <link href="/images/favicon/apple-icon-57x57.png;Bigkinds=C603A927C7895A8376A58D17ED532233" rel="apple-touch-icon" sizes="57x57"/>
# <link href="/images/favicon/apple-icon-60x60.png;Bigkinds=C603A927C7895A8376A58D17ED532233" rel="apple-touch-icon" sizes="60x60"/>
# <link href="/images/favicon/apple-icon-72x72.png;Bigkinds=C603A927C7895A8376A58D17ED532233" rel="apple-touch-icon" sizes="72x72"/>
# <link href="/images/favicon/apple-icon-76x76.png;Bigkinds=C603A927C7895A8376A58D17ED532233" rel="apple-touch-icon" sizes="76x76"/>
# <link href="/images/favicon/apple-icon-114x114.png;Bigkinds=C603A927C7895A8376A58D17ED532233" rel="apple-touch-icon" sizes="114x114"/>
# <link href="/images/favicon/apple-icon-120x120.png;Bigkinds=C603A927C7895A8376A58D17ED532233" rel="apple-touch-icon" sizes="120x120"/>
# ...
