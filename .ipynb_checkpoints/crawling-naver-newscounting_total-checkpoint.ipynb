# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import requests
import time
import datetime as dt
import pandas as pd
from urllib.request import urlopen
import re
import datetime
import pymysql

# %%
"""
월초, 월말 리스트 저장
freq: ms-월초 m-월말
"""
today = datetime.date.today().strftime('%Y.%m.%d')
start_dates = pd.date_range(start = '2008-07-01', end = today, freq = 'W-MON')
end_dates = pd.date_range(start = '2008-07-13', end = today, freq = '7d')

def getDate(start_dates, end_dates, i):
    start_dates = start_dates.strftime('%Y.%m.%d')
    end_dates = end_dates.strftime('%Y.%m.%d')
    
    return start_dates[i], end_dates[i]

# %%
"""
검색 target: 네이버뉴스
검색 keyword: 경제
기간: start_date ~ end_date(한 달)
"""
def getNewsCountingFromHTML(start_date, end_date):
    raw_html = urlopen('https://search.naver.com/search.naver?where=news&query=%EA%B8%B0%EC%9E%90&sm=tab_opt&sort=0&photo=0&field=0&reporter_article=&pd=3&ds='+start_date+'&de='+end_date+'&docid=&nso=so%3Ar%2Cp%3A')
    html = BeautifulSoup(raw_html, 'html.parser')
    count_tag = html.find_all("div", {"class": "title_desc all_my"})
    news_cnt = count_tag[0].get_text()[7:]
    
    return news_cnt

# %%
"""
'keyword에 대한 뉴스 기사 건수
str을 int로 변환 
ex. 3,277건 --> 3277
"""
def extract_only_counting(text):
    regex = re.compile(r'((-)?\d{1,3}(,\d{3})*(\.\d+)?)')
    search = regex.search(text)
    
    if search:
        return int(search.group(1).replace(',',''))
    else:
        return 0

# %%
conn = pymysql.connect(host = "127.0.0.1", user = [USER], passwd = [PASSWORD], db = [DATABASE])
cur = conn.cursor()

# %%
"""
news counting 정보 저장할 table 생성
"""

create_table_query = """
CREATE TABLE IF NOT EXISTS news_counting_total(
    id BIGINT(7) NOT NULL AUTO_INCREMENT,
    year bigint(4) NOT NULL,
    month bigint(2) NOT NULL,
    day bigint(2) NOT NULL, 
    cnt bigint(100),
    primary key(id) )
    charset=utf8mb4;
"""
cur.execute(create_table_query)
# charset=utf8mb4; 유니코드 스트링 저장
# Out:
# 0

# %%
cur.execute("desc news_counting_total")
table = cur.fetchall()
pd.DataFrame(list(table))
# Out:
#        0            1    2    3     4               5
# 0     id    bigint(7)   NO  PRI  None  auto_increment
# 1   year    bigint(4)   NO       None
# 2  month    bigint(2)   NO       None
# 3    day    bigint(2)   NO       None
# 4    cnt  bigint(100)  YES       None

# %%
start_date, end_date = getDate(start_dates, end_dates, 0)
start_date
# Out:
# '2008.07.07'

# %%
"""
db table에 저장
"""

for i in range(len(start_dates)-1):
    query = """ 
    Insert into news_counting_total (year, month, day, cnt) values (%d, %d, %d, %d) ;
    """
    start_date, end_date = getDate(start_dates, end_dates, i)
    news_cnt = getNewsCountingFromHTML(start_date, end_date)
    news_cnt = extract_only_counting(news_cnt)

    mystring = (query % (int(start_date[0:4]), int(start_date[5:7]), int(start_date[8:10]), news_cnt))
    print(mystring)
    cur.execute(mystring)
# Out:
#
#     Insert into news_counting_total (year, month, day, cnt) values (2008, 7, 7, 9144) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2008, 7, 14, 9185) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2008, 7, 21, 8408) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2008,
;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2018, 10, 29, 223185) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2018, 11, 5, 138841) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2018, 11, 12, 91153) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2018, 11, 19, 54855) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2018, 11, 26, 55588) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2018, 12, 3, 55421) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2018, 12, 10, 55818) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2018, 12, 17, 53921) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2018, 12, 24, 43057) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2018, 12, 31, 45567) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2019, 1, 7, 62083) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2019, 1, 14, 59287) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2019, 1, 21, 62822) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2019, 1, 28, 56526) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2019, 2, 4, 30313) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2019, 2, 11, 56747) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2019, 2, 18, 57218) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2019, 2, 25, 57759) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2019, 3, 4, 60774) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2019, 3, 11, 61911) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2019, 3, 18, 65546) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2019, 3, 25, 63528) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2019, 4, 1, 64957) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2019, 4, 8, 63781) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2019, 4, 15, 65478) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2019, 4, 22, 66029) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2019, 4, 29, 61721) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2019, 5, 6, 60983) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2019, 5, 13, 70820) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2019, 5, 20, 73130) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2019, 5, 27, 75583) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2019, 6, 3, 68013) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2019, 6, 10, 75381) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2019, 6, 17, 75444) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2019, 6, 24, 78852) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2019, 7, 1, 75259) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2019, 7, 8, 73370) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2019, 7, 15, 75374) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2019, 7, 22, 74754) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2019, 7, 29, 71361) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2019, 8, 5, 72595) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2019, 8, 12, 63988) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2019, 8, 19, 73568) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2019, 8, 26, 74517) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2019, 9, 2, 83960) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2019, 9, 9, 54385) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2019, 9, 16, 73176) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2019, 9, 23, 73893) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2019, 9, 30, 66663) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2019, 10, 7, 63447) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2019, 10, 14, 72749) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2019, 10, 21, 78414) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2019, 10, 28, 77808) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2019, 11, 4, 77330) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2019, 11, 11, 79152) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2019, 11, 18, 77594) ;
#
#     Insert into news_counting_total (year, month, day, cnt) values (2019, 11, 25, 76921) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2019, 12, 2, 76397) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2019, 12, 9, 76080) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2019, 12, 16, 77446) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2019, 12, 23, 64391) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2019, 12, 30, 62616) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2020, 1, 6, 74633) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2020, 1, 13, 78407) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2020, 1, 20, 62699) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2020, 1, 27, 68697) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2020, 2, 3, 76826) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2020, 2, 10, 74403) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2020, 2, 17, 79951) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2020, 2, 24, 82073) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2020, 3, 2, 80162) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2020, 3, 9, 76809) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2020, 3, 16, 82020) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2020, 3, 23, 81692) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2020, 3, 30, 79834) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2020, 4, 6, 77111) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2020, 4, 13, 68055) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2020, 4, 20, 74656) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2020, 4, 27, 61100) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2020, 5, 4, 63908) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2020, 5, 11, 74993) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2020, 5, 18, 72854) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2020, 5, 25, 78830) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2020, 6, 1, 74974) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2020, 6, 8, 73029) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2020, 6, 15, 73814) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2020, 6, 22, 76940) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2020, 6, 29, 79658) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2020, 7, 6, 76328) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2020, 7, 13, 72752) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2020, 7, 20, 72978) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2020, 7, 27, 69922) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2020, 8, 3, 65889) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2020, 8, 10, 66562) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2020, 8, 17, 62812) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2020, 8, 24, 69143) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2020, 8, 31, 69676) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2020, 9, 7, 67086) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2020, 9, 14, 69582) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2020, 9, 21, 74443) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2020, 9, 28, 43301) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2020, 10, 5, 66071) ;
#
#
#     Insert into news_counting_total (year, month, day, cnt) values (2020, 10, 12, 73249) ;

# %%
# 확인
query = """ 
select * from news_counting_total ;
"""
cur.execute(query)
tmp=pd.DataFrame(list(cur.fetchall()))
tmp
# Out:
#        0     1   2   3      4
# 0      1  2008   7   7   9144
# 1      2  2008   7  14   9185
# 2      3  2008   7  21   8408
# 3      4  2008   7  28   8617
# 4      5  2008   8   4   8519
# ..   ...   ...  ..  ..    ...
# 636  637  2020   9  14  69582
# 637  638  2020   9  21  74443
# 638  639  2020   9  28  43301
# 639  640  2020  10   5  66071
# 640  641  2020  10  12  73249
#
# [641 rows x 5 columns]

# %%
conn.commit()
cur.close()
conn.close()
